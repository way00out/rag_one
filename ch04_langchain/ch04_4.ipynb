# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\hanhwa0902\ex0914\.0914venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

load_dotenv
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
import logging
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_teddynote.messages import stream_response

# %%
logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    encoding="utf-8"
)

logger = logging.getLogger("MyMultimodalApp")

logger.info("LangSmith 연동 및 애플리케이션 시작2")

try:
    multimodal_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.1)

    IMAGE_URL = "https://t3.ftcdn.net/jpg/03/77/33/96/360_F_377339633_Rtv9I77sSmSNcev8bEcnVxTHrXB4nRJ5.jpg"
    prompt = "이미지의 내용을 한국어로 상세히 설명해 주세요"

    logger.info(f"요청 전송 - Prompt: {prompt} / image: {IMAGE_URL}")

    message = HumanMessage(
        content=[
            {"type": "text", "text": prompt},
            {"type": "image_url", "image_url": {"url": IMAGE_URL}},
        ]
    )

    answer = multimodal_llm.stream([message])

    logger.info("답변 수신 및 스트리밍 시작")
    stream_response(answer)
    logger.info("답변 처리 완료")

except Exception as e:
    logger.error(f"실행 중 에러 발생: {str(e)}", exc_info=True)
# Out:
# 이 이미지는 표 형식으로 구성된 데이터입니다. 표의 제목은 "TABLE 001: LOREM IPSUM DOLOR AMIS ENIMA ACCUMMER TUNA"입니다. 표는 여러 열로 나뉘어 있으며, 각 열은 다음과 같은 항목을 포함하고 있습니다:
#
# 1. **첫 번째 열**: 항목 이름 (예: "Lorem dolor siamet", "Consecter odio" 등)
# 2. **두 번째 열**: 숫자 데이터 (예: 8,288, 123 등)
# 3. **세 번째 열**: 백분율 (예: 123%, 87% 등)
# 4. **네 번째 열**: "YES" 또는 "NO"와 같은 상태 표시
# 5. **다섯 번째 열**: 가격 정보 (예: $89, $129 등)
#
# 각 행은 특정 항목에 대한 정보를 제공하며, 마지막 행에는 "N/A"라는 값이 포함되어 있습니다. 표의 내용은 일반적으로 데이터 분석이나 보고서 작성에 사용될 수 있는 형식입니다.
