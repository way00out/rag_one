# %% [markdown]
# ### Excel

# %%
# !pip --version
# Out:
# pip 25.0.1 from C:\Users\rbehd\Desktop\coding\ex\.exvenv\Lib\site-packages\pip (python 3.12)

# %%
# !pip install -qU langchain-community unstructured openpyxl

# %%
# !pip install networkx

# %%
from langchain_community.document_loaders import UnstructuredExcelLoader

loader = UnstructuredExcelLoader("./data/titanic.xlsx", mode="elements")

docs = loader.load()

print(len(docs))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       1 from langchain_community.document_loaders import UnstructuredExcelLoader
#       2
#       3 loader = UnstructuredExcelLoader("./data/titanic.xlsx", mode="elements")
#       4
# ----> 5 docs = loader.load()
#       6
#       7 print(len(docs))
#
# File ~\Desktop\coding\ex\.exvenv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File ~\Desktop\coding\ex\.exvenv\Lib\site-packages\langchain_community\document_loaders\unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File ~\Desktop\coding\ex\.exvenv\Lib\site-packages\langchain_community\document_loaders\excel.py:50, in UnstructuredExcelLoader._get_elements(self)
#      49 def _get_elements(self) -> List:
# ---> 50     from unstructured.partition.xlsx import partition_xlsx
#      52     return partition_xlsx(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~\Desktop\coding\ex\.exvenv\Lib\site-packages\unstructured\partition\xlsx.py:12
#      10 import numpy as np
#      11 import pandas as pd
# ---> 12 from msoffcrypto import OfficeFile
#      13 from msoffcrypto.exceptions import FileFormatError
#      14 from typing_extensions import Self, TypeAlias
#
# ModuleNotFoundError: No module named 'msoffcrypto'
