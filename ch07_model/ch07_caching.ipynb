# %% [markdown]
# ### Cache

# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\hanhwa0902\ex0917\.0917venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_teddynote import logging

logging.langsmith("test0917")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# test0917

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

llm = ChatOpenAI(model="gpt-3.5-turbo")

prompt = PromptTemplate.from_template("{country} 에 대해서 200자 내외로 요약해줘")

chain = prompt | llm

# %%
# %%time
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 대한민국과 조선민주주의인민공화국으로 구성된 한반도의 국가이다. 고도의 경제력과 기술력을 보유한 선진국가로 발전하였으며 문화, 역사, 음식, K-pop, 드라마 등이 세계적으로 인기를 끌고 있다. 한반도의 자율주의와 불교, 천주교, 기독교, 유교 등 다양한 종교가 공존하고 있다. 수도는 서울이며 경복궁, 인사동, 명동, 홍대 등이 관광명소로 유명하다. 미국과 중국, 일본과의 관계가 중요하며 북한과의 관계는 계속적인 긴장 상태에 있다. 최근에는 한류 열풍이 전 세계에 영향을 주고 있으며 세계적으로 영향력 있는 국가로 자리매김하고 있다.
# CPU times: total: 219 ms
# Wall time: 2.81 s

# %% [markdown]
# ### InMemoryCache

# %%
# !pip install langchain-core

# %%
# %%time
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache

set_llm_cache(InMemoryCache())

response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 대한민국과 조선민주주의인민공화국으로 구성된 한반도의 국가이다. 경제적으로는 선진국가로 발전한 대한민국과 북한과의 긴장 관계 속에서 빠르게 발전하는 조선민주주의인민공화국으로 이루어져 있다. 한국은 고도의 IT 기술과 자동차, 반도체, 조선, 미디어 등 다양한 산업을 보유하고 있으며 K-pop, K-drama와 같은 문화 콘텐츠로 국제적으로도 큰 인기를 끌고 있다. 또한 한국은 전통문화와 현대 문화의 조화, 강력한 경제력, 미래 산업에 대한 투자 등으로 국제사회에서 주목을 받고 있는 나라이다.
# CPU times: total: 46.9 ms
# Wall time: 2.05 s

# %%
# %%time
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 대한민국과 조선민주주의인민공화국으로 구성된 한반도의 국가이다. 경제적으로는 선진국가로 발전한 대한민국과 북한과의 긴장 관계 속에서 빠르게 발전하는 조선민주주의인민공화국으로 이루어져 있다. 한국은 고도의 IT 기술과 자동차, 반도체, 조선, 미디어 등 다양한 산업을 보유하고 있으며 K-pop, K-drama와 같은 문화 콘텐츠로 국제적으로도 큰 인기를 끌고 있다. 또한 한국은 전통문화와 현대 문화의 조화, 강력한 경제력, 미래 산업에 대한 투자 등으로 국제사회에서 주목을 받고 있는 나라이다.
# CPU times: total: 15.6 ms
# Wall time: 2.16 ms

# %% [markdown]
# ### SQLite Cache

# %%
from langchain_community.cache import SQLiteCache
from langchain_core.globals import set_llm_cache
import os

if not os.path.exists("cache"):
    os.makedirs("cache")

set_llm_cache(SQLiteCache(database_path="cache/llm_cache.db"))

# %%
# %%time
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 고도로 발전한 국가이다. 대한민국과 조선민주주의인민공화국으로 나뉘어져 있으며, 수도는 서울에 위치한다. 한국은 세계적으로 유명한 K-pop, K-drama, 한류 등의 문화 콘텐츠로 인해 인기를 끌고 있으며, 또한 기술과 경제 분야에서도 선진국가로 인정받고 있다. 한국은 역동적인 혼합문화를 가지고 있으며, 전통문화와 현대 문화가 조화를 이루고 있다. 또한 한국은 맛있는 음식과 아름다운 여행지로도 유명하며, 한국의 자연환경 역시 아름다움으로 유명하다. 최근에는 K-배연, K-스포츠 등의 분야에서도 글로벌 경연이 활발해지고 있다.
# CPU times: total: 46.9 ms
# Wall time: 4.28 s
