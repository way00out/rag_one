# %% [markdown]
# ### ConversationEntityMemory
#
# - llm을 사용하여 정보를 추출하고 지식을 축적

# %%
# !pip --version
# Out:
# pip 26.2.1 from d:\hanhwa0902\ex0918\.0918venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_classic.chains import ConversationChain
from langchain_classic.memory import ConversationEntityMemory
from langchain_classic.memory.prompt import ENTITY_MEMORY_CONVERSATION_TEMPLATE

# %%
print(ENTITY_MEMORY_CONVERSATION_TEMPLATE.template)
# Out:
# You are an assistant to a human, powered by a large language model trained by OpenAI.
#
# You are designed to be able to assist with a wide range of tasks, from answering simple questions to providing in-depth explanations and discussions on a wide range of topics. As a language model, you are able to generate human-like text based on the input you receive, allowing you to engage in natural-sounding conversations and provide responses that are coherent and relevant to the topic at hand.
#
# You are constantly learning and improving, and your capabilities are constantly evolving. You are able to process and understand large amounts of text, and can use this knowledge to provide accurate and informative responses to a wide range of questions. You have access to some personalized information provided by the human in the Context section below. Additionally, you are able to generate your own text based on the input you receive, allowing you to engage in discussions and provide explanations and descriptions on a wide range of topics.
#
# Overall, you are a powerful tool that can help with a wide range of tasks and provide valuable insights and information on a wide range of topics. Whether the human needs help with a specific question or just wants to have a conversation about a particular topic, you are here to assist.
#
# Context:
# {entities}
#
# Current conversation:
# {history}
# Last line:
# Human: {input}
# You:

# %%
llm = ChatOpenAI(model="gpt-5-mini", temperature=0)

conversation = ConversationChain(
    llm=llm,
    prompt=ENTITY_MEMORY_CONVERSATION_TEMPLATE,
    memory=ConversationEntityMemory(llm=llm),
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14588\224069153.py:6: LangChainDeprecationWarning: The class `ConversationEntityMemory` was deprecated in LangChain 0.3.1 and will be removed in 2.0.0. Use `langchain.agents.create_agent` instead. For agents that need to remember prior interactions, use `create_agent` with checkpointing or the `Store` API. See https://docs.langchain.com/oss/python/langchain/short-term-memory and https://docs.langchain.com/oss/python/langchain/long-term-memory
#   memory=ConversationEntityMemory(llm=llm),
# C:\Users\user\AppData\Local\Temp\ipykernel_14588\224069153.py:3: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 2.0.0. Use `langchain.agents.create_agent` instead. Build a conversational agent with `langchain.agents.create_agent` and persist message history via a LangGraph checkpointer.
#   conversation = ConversationChain(

# %%
conversation.predict(
    input="테디와 셜리는 한 회사에서 일하는 동료입니다."
    "테디는 개발자이고 셜리는 디자이너입니다."
    "그들은 최근 회사에서 일하는 것을 그만두고 자신들의 회사를 차릴 계획을 세우고 있습니다."
)
# Out:
# '멋진 계획이에요 — 축하합니다. 테디(개발자)와 셜리(디자이너)가 스타트업을 함께 시작할 때 초반에 해두면 좋은 실무적이고 실용적인 단계들을 정리해드릴게요. 원하시면 각 항목에 대한 템플릿(비즈니스플랜/피치덱/재무모델/MVP 로드맵 등)도 바로 만들어 드립니다.\n\n1) 핵심 정리 (1–2일)\n- 비전/미션: 무슨 문제를 누가 어떻게 해결하려는지 한 문장으로.\n- 핵심가설: 고객, 문제, 솔루션의 가정들을 목록화.\n\n2) 역할과 의사결정 구조 명확화 (1–2일)\n- CTO(제품/아키텍처/인프라) vs CPO/디자인(UX·브랜딩·제품우선순위) 등 책임 분담 정의.\n- 중요한 의사결정(채용, 투자, 법인구조 등) 시 합의 방식(동의 비율, 벤토조치) 정하기.\n\n3) 고객 검증(고객발견) — 가장 먼저 할 일(2–6주)\n- 타깃 고객 10–50명 인터뷰: 문제의 심각성, 기존 대안, 지불 의사 확인.\n- 간단한 랜딩페이지/A/B 실험 또는 광고로 관심(이메일/클릭) 측정.\n- 핵심지표 정의: 활성사용자, 전환율, CAC, LTV(초기 가설).\n\n4) 최소기능제품(MVP) 설계·우선순위(2–8주)\n- Must-have 기능만 추려 1–2주 내 프로토타입(디자인 클릭형) → 2–4주 내 베타배포.\n- 셜리는 인터랙티브 프로토타입(Figma 등), 테디는 빠른 빌드(서버리스/노코드/빠른 프레임워크).\n- 측정 가능한 실험 설계(목표 + 성공 기준).\n\n5) 회사·법률·회계(초기 세팅)\n- 사업자 형태 결정: 개인사업자 vs 법인(주식회사 등). (법인 필요성, 투자 계획, 책임 범위에 따라 결정)\n- 필수: 사업자등록, 은행계좌, 기본 계약서(공동창업자/주주간 합의서), 개인정보·이용약관/서비스 약관 초안.\n- 세무사 상담 권장(초기 법인 설립/세금 혜택·지원금 안내).\n- 한국 지원: 창업지원센터/창업진흥원, 정부 R&D/창업자금/보증대출 정보를 확인.\n\n6) 자금 계획(런웨이) 및 자금조달 옵션\n- 6–12개월 비용(급여, 서버, 마케팅, 기타) 기반 런웨이 산정.\n- 초기 옵션: 부트스트랩(자체), 엔젤투자, 정부지원금·창업지원, 액셀러레이터 프로그램.\n- 투자 준비: 피치덱(문제·해결·시장·비즈니스모델·팀·재무), 데이터(고객 검증 결과).\n\n7) 브랜딩·마케팅 초기전략\n- 핵심 메시지/포지셔닝, 브랜드 아이덴티티(로고·톤), 랜딩 페이지.\n- 초기 채널: 콘텐츠(블로그/레터), 커뮤니티(카페/슬랙/페북), 퍼포먼스(검색/소셜 광고).\n- 셜리가 디자인 리드로 브랜드 자산(스타일 가이드, 컴포넌트 라이브러리) 준비.\n\n8) 기술·디자인 워크플로우·도구\n- 협업 도구: Figma, Git(GitHub/GitLab), Jira/Trello/Notion, Slack/Discord, CI/CD(예: GitHub Actions).\n- 디자인-개발 핸드오프: 컴포넌트 라이브러리, Storybook, 디자인시스템.\n- 초기 스택 제안(빠른 배포와 비용 효율 고려): 프론트엔드(Next.js/Vue), 백엔드(serverless 또는 Node/Go), DB(Firebase/Postgres), 호스팅(Vercel/Netlify, AWS/GCP).\n\n9) 채용·외주 전략\n- 초기엔 핵심 역량(제품·마케팅)에 집중, 필요 시 프리랜서(개발·QA·마케팅) 활용.\n- 채용 시 문화/가치 중심으로 적합성 확인.\n\n10) 위험 관리·지속 점검\n- 정기 미팅(주간 스탠드업, 월간 전략), KPI 대시보드.\n- 나중에 발생할 수 있는 갈등 대비: 창업자간 주식/보상/퇴사 규정 문서화.\n\n예상 타임라인(초기 3개월 예시)\n- 0–2주: 비전, 역할, 고객가설 정리\n- 2–6주: 고객인터뷰, 랜딩페이지→트래픽 실험\n- 6–12주: MVP 개발·베타 론칭, 초기 사용자 피드백 반복\n- 3개월: 피드백 기반 PMF(제품/시장 적합성) 판단 및 투자·스케일 전략 수립\n\n도움이 될 만한 리소스\n- 책: Lean Startup(린스타트업), 고객개발(Customer Development)\n- 자료: Y Combinator Startup Library, 국내 창업지원 포털(창업진흥원 등)\n- 템플릿: 피치덱(10슬라이드), 12~24개월 간단 재무 모델, 고객 인터뷰 가이드\n\n원하시면 다음 중 하나를 바로 만들어 드릴게요:\n- 1페이지 비즈니스 캔버스(가설 중심)\n- 10슬라이드 피치덱 초안\n- 3개월 MVP 로드맵(주간할일 포함)\n- 초기 재무(런웨이) 계산기 템플릿\n\n어떤 걸 먼저 도와드릴까요? 그리고 간단히: 지금 생각하는 사업 아이템(또는 해결하고 싶은 문제)과 준비 가능한 예산/퇴사 예정 시점 알려주시면 더 구체적으로 맞춤 플랜을 드리겠습니다.'

# %%
conversation.memory.entity_store.store
# Out:
# {'테디': '테디는 같은 회사에 다니는 개발자이며 셜리와 함께 최근 퇴사해 자신들의 회사를 차릴 계획을 세우고 있다.',
#  '셜리': '셜리는 같은 회사에서 테디와 함께 일하는 디자이너이며, 최근 현재 직장을 그만두고 테디와 함께 회사를 창업할 계획을 세우고 있다.'}
