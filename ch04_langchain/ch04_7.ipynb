# %%
# !pip --version
# Out:
# pip 26.2.1 from D:\hanhwa0902\ex0914\.0914venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model = ChatOpenAI()

prompt = PromptTemplate.from_template("{topic} 에 대하여 3문장으로 설명해줘.")

chain = prompt | model | StrOutputParser()

# %%
chain
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='{topic} 에 대하여 3문장으로 설명해줘.')
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000027A2363AA50>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000027A242A60F0>, root_client=<openai.OpenAI object at 0x0000027A235068A0>, root_async_client=<openai.AsyncOpenAI object at 0x0000027A24088500>, model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)
# | StrOutputParser()

# %%
chain.batch([{"topic":"ChatGPT"}, {"topic":"Instagram"}])
# Out:
# ['ChatGPT는 자연어 처리 기술을 기반으로 대화를 주도하고 응답하는 인공지능 챗봇이다. ChatGPT는 다양한 주제에 대한 대화를 할 수 있으며, 사용자들이 학습하거나 정보를 얻기 위해 사용할 수 있다. ChatGPT는 계속적으로 학습하고 발전하며, 더 자연스러운 대화를 위해 노력하고 있다.',
#  'Instagram은 사진과 동영상을 공유하는 소셜 미디어 애플리케이션입니다. 사용자들은 팔로워와 팔로잉을 통해 다른 사람들의 콘텐츠를 감상하고 자신의 일상을 공유할 수 있습니다. 또한 인스타그램 스토리 기능을 통해 실시간으로 이모티콘, 스티커, 텍스트 등 다양한 콘텐츠를 제작하여 공유할 수 있습니다.']

# %%
answer = chain.batch([{"topic":"ChatGPT"}, {"topic":"Instargram"}])
print(answer)
print(answer[0])
# Out:
# ['ChatGPT는 GPT-3 기술을 기반으로 한 대화형 인공지능 챗봇 서비스이다. 이를 통해 사용자들은 자연스러운 대화를 통해 다양한 주제에 대한 정보나 질문에 답변을 받을 수 있다. ChatGPT는 커뮤니케이션, 학습, 엔터테인먼트 등 다양한 분야에서 활용될 수 있다.', 'Instagram은 사진과 동영상을 공유할 수 있는 소셜 미디어 플랫폼이다. 사용자들은 팔로워들과 소통하며 일상을 공유하고 다양한 콘텐츠를 즐길 수 있다. 해시태그를 통해 관심사에 맞는 콘텐츠를 검색하고 탐색할 수 있다.']
# ChatGPT는 GPT-3 기술을 기반으로 한 대화형 인공지능 챗봇 서비스이다. 이를 통해 사용자들은 자연스러운 대화를 통해 다양한 주제에 대한 정보나 질문에 답변을 받을 수 있다. ChatGPT는 커뮤니케이션, 학습, 엔터테인먼트 등 다양한 분야에서 활용될 수 있다.

# %%
chain.batch(
    [
        {"topic": "ChatGPT"},
        {"topic": "Instagram"},
        {"topic": "멀티모달"},
        {"topic": "프로그래밍"},
        {"topic": "머신러닝"},
    ],
    config={"max_concurrency": 3},
)
# Out:
# ['ChatGPT는 대화형 인공지능으로, 자연어 처리 기술을 이용해 다양한 주제에 대해 대화할 수 있습니다. 사용자의 질문에 답변하거나 대화를 이어나가며 상황에 맞는 정보를 제공합니다. 이 AI는 감정을 이해하고 언어 장애인이나 회사 고객 서비스에서도 유용하게 활용될 수 있습니다.',
#  'Instagram은 사진과 동영상을 공유할 수 있는 소셜 미디어 플랫폼이다. 서로를 팔로우하고 소통하는 기능을 제공하여 사용자들 간의 소셜 네트워크를 형성한다. 해시태그 기능을 통해 관심사나 주제별로 다양한 콘텐츠를 쉽게 찾아볼 수 있다.',
#  '멀티모달이란 여러가지 형태의 다양한 입력과 출력 방식을 통해 사용자와 상호작용하는 시스템을 말합니다. 이는 음성, 텍스트, 이미지, 동영상 등 다양한 형태의 데이터를 동시에 처리하고 활용할 수 있게 해줍니다. 멀티모달은 사용자 경험을 향상시키고 보다 효율적이고 편리한 서비스를 제공하는데 도움을 줍니다.',
#  '프로그래밍이란 컴퓨터에게 실행할 작업을 지시하는 일종의 커뮤니케이션 방법입니다. 이를 통해 우리는 컴퓨터를 활용하여 원하는 결과를 얻을 수 있습니다. 프로그래밍은 코드를 작성하고 디버깅하는 과정을 통해 문제 해결 능력을 기르는데 도움이 됩니다.',
#  '머신러닝은 컴퓨터가 특정 작업을 수행할 수 있도록 학습하는 인공지능 기술로, 데이터를 기반으로 패턴을 학습하고 예측을 수행한다. 다양한 알고리즘을 사용하여 데이터를 분석하고 모델을 만들어 예측을 수행하는데, 학습을 통해 모델이 점차적으로 성능을 향상시킨다. 머신러닝은 이미지 인식, 자연어 처리, 추천 시스템 등 다양한 분야에서 활발히 활용되고 있다.']

# %%
async for token in chain.astream({"topic": "YouTube"}):
    print(token, end="", flush=True)
# Out:
# YouTube는 동영상 공유 플랫폼으로 사용자들이 영상을 업로드하고 시청할 수 있는 서비스이다. 영상 콘텐츠의 다양성과 무료로 이용 가능한 점이 많은 사람들에게 인기를 끌고 있다. 또한 광고 수익을 통해 유명한 크리에이터들이 수익을 창출할 수 있도록 도와주는 역할을 하고 있다.

# %%
my_process = chain.ainvoke({"topic": "NVDA"})

# %%
await my_process
# Out:
# 'NVDA는 NVIDIA Corporation의 주식 코드이다.\n\nNVDA는 그래픽 처리 장치 및 컴퓨팅 기술 분야에서 세계적인 기업으로, 주로 게임 산업 및 인공지능 분야에서 강력한 영향력을 가지고 있다.\n\nNVDA 주가는 기술 시장의 흥행에 크게 영향을 받으며, 투자자들에게 큰 주목을 받는 주식 중 하나이다.'
